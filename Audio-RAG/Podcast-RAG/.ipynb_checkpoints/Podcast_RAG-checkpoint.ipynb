# %% [markdown]
# # Podcast RAG

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Workflow

# %% [markdown]
# ## Import necessary packages

# %% [markdown]
# Import all the necessary packages and libraries

# %%
import feedparser
import ipywidgets as widgets
from IPython.display import display

PODCAST_URL = "https://feed.podbean.com/openatintel/feed.xml"

feed = feedparser.parse(PODCAST_URL)
episodes = []

for entry in feed.entries:
    audio_url = None    
    if not audio_url and hasattr(entry, 'enclosures') and entry.enclosures:
        audio_url = entry.enclosures[0].href
    
    if audio_url:
        episodes.append({'title': entry.title, 'url': audio_url})

print('Found', len(episodes), 'episodes')

episode_titles = [ep['title'] for ep in episodes]

dropdown = widgets.Dropdown(
    options=episode_titles,
    value=episode_titles[0],
    description='Episode:'
)

display(dropdown)
# Out:
# Found 100 episodes
# Dropdown(description='Episode:', options=('Building Innovation with Open Source AI', 'Democratizing Kubernetes…

# %%
selected_index = dropdown.index
selected_url = episodes[selected_index]['url']

print(f"Selected: {episodes[selected_index]['title']}")
print(f"Audio URL: {selected_url}")
# Out:
# Selected: Building Innovation with Open Source AI
# Audio URL: https://mcdn.podbean.com/mf/web/39af5nsnhjy8ckxr/OpenAtIntel_Ep111_MelissaMcKay-JFrog.mp3

# %%
# %%time

import requests
import torch
import torchaudio
from transformers import WhisperProcessor, WhisperForConditionalGeneration
import os
from urllib.parse import urlparse
import feedparser


MODEL_SIZE = "openai/whisper-base"
processor = WhisperProcessor.from_pretrained(MODEL_SIZE)
model = WhisperForConditionalGeneration.from_pretrained(MODEL_SIZE)
model = model.to('xpu')
print("Model loaded!")

OUTPUT_DIR = "downloads"
print(f"Downloading audio from: {selected_url}")
os.makedirs(OUTPUT_DIR, exist_ok=True)
filename = os.path.basename(urlparse(selected_url).path)
audio_path = os.path.join(OUTPUT_DIR, filename)

response = requests.get(selected_url)
with open(audio_path, 'wb') as f:
    f.write(response.content)

print(f"Audio saved to: {audio_path}")
# Out:
# Model loaded!
# Downloading audio from: https://mcdn.podbean.com/mf/web/39af5nsnhjy8ckxr/OpenAtIntel_Ep111_MelissaMcKay-JFrog.mp3
# Audio saved to: downloads\OpenAtIntel_Ep111_MelissaMcKay-JFrog.mp3
# CPU times: total: 7.53 s
# Wall time: 9.73 s

# %%
print("Transcribing audio... (this may take a few minutes)")

waveform, sample_rate = torchaudio.load(audio_path)
print(f"Original sample rate: {sample_rate} Hz")
print(f"Audio shape: {waveform.shape}")

if waveform.shape[0] > 1:
    waveform = torch.mean(waveform, dim=0, keepdim=True)
    print("Converted stereo to mono")

if sample_rate != 16000:
    resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)
    waveform = resampler(waveform)
    sample_rate = 16000
    print("Resampled to 16kHz")
    print(f"Audio shape: {waveform.shape}")

audio = waveform.squeeze().numpy()
print(f"Audio duration: {len(audio)/sample_rate:.1f} seconds")

chunk_length = 22 * 16000  # 22 seconds
overlap_length = 1 * 16000  # 1 second overlap

transcription_parts = []
total_chunks = len(audio) // chunk_length + (1 if len(audio) % chunk_length > 0 else 0)

print(f"Processing {total_chunks} chunks of audio..")
for i in range(0, len(audio), chunk_length - overlap_length):
    chunk = audio[i:i + chunk_length]
    
    if len(chunk) < 1600:  # Less than 0.1 seconds, skip that chunk
        continue
    
    print(f"Processing chunk {len(transcription_parts) + 1}/{total_chunks}...")
    
    input_features = processor(chunk, sampling_rate=16000, return_tensors="pt").input_features
    input_features = input_features.to('xpu')
    with torch.no_grad():
        predicted_ids = model.generate(input_features)
        
    chunk_transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)[0]
    
    # if chunk_transcription.strip():
    # transcription_parts.append(chunk_transcription.strip())
    transcription_parts.append(chunk_transcription)
    print(f"Chunk {len(transcription_parts)}: {chunk_transcription}..")

transcription = " ".join(transcription_parts)
print(f"\n\n Total length: {len(transcription)} characters")

print(f"Audio path: {audio_path}")
print(f"Word count: {len(transcription.split())}")
print(transcription)
# Out:
# Transcribing audio... (this may take a few minutes)
# Original sample rate: 44100 Hz
# Audio shape: torch.Size([2, 64359798])
# Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# Converted stereo to mono
# Resampled to 16kHz
# Audio shape: torch.Size([1, 23350494])
# Audio duration: 1459.4 seconds
# Processing 67 chunks of audio..
# Processing chunk 1/67...
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Chunk 1:  My company was really interested in getting involved in this product called a Kia. So it's, you know, an attempt to standardize this. To put things together in such a way that everyone can do it the same, we can all contribute, we can all pay attention to the details. Welcome to the OpenItIntel podcast, where we're all about open source from software..
# Processing chunk 2/67...
# Chunk 2:  source from software to security to innovation and beyond. I'm your host, Catherine Druckmann, an open source evangelist at Intel, bringing you leading edge, free-ranging conversations from some of the best minds in the open source community. Let's get into it! I spoke with Melissa McCay of J. Frog about the excitement and challenges in developing generative AI applications..
# Processing chunk 3/67...
# Chunk 3:  applications, and why open source participation is so critical to fostering growth and innovation and technology. Join us. Hey Melissa, thank you for joining me. I really appreciate you sitting down and taking the time out of your day to talk to me about Oatspull or AI and stuff. Thank you. Yeah, Asurin is always a pleasure for sure...
# Processing chunk 4/67...
# Chunk 4:  So first, why don't you tell us a little bit more about who you are and what you do and especially what you do in open source communities? Okay, cool. I think this is always a valuable question because I think there's a lot of folks out there that don't realize there's a lot of different personas and different types of people that are contributing to open source. And if you think that you are too late to the game or not technical..
# Processing chunk 5/67...
# Chunk 5:  or not technical enough, that is not a good enough reason to not be able to contribute to open source projects. So there's lots of different ways to do that. I began, I was a developer, principal developer at my last position, so a lot of my career has been just, you know, being low on the table, just being, you know, sitting at my desk and grabbing tasks off of Jira and, you know,..
# Processing chunk 6/67...
# Chunk 6:  I am fixing bugs. And so dealing with open source for me for the most part, especially in the beginning of my career, was just using it. Right? And I didn't really understand the whole ecosystem behind it. I just had a job to do and that's what I did every day. Then as you get more experience and more exposure, you start meeting different people, maybe..
# Processing chunk 7/67...
# Chunk 7:  people, maybe you go to a few conferences, you start realizing, oh wow, this is a lot bigger world than I realized. And that's exactly what happened. Then I started getting aware and more involved in foundations. That was probably the big stepping stone for me getting involved with open source communities, at all. Starting to learn how they worked, how they..
# Processing chunk 8/67...
# Chunk 8:  they worked, how they give these projects a little more credibility when they go through the process of improvement and being able to have the communities in these projects that make them better, make them reliable. You have the maintainers you can reach out to. So that's where I started. Since then, being able to be involved with these communities..
# Processing chunk 9/67...
# Chunk 9:  I can give one specific example that I'm kind of really excited about because it happened recently. My company, I work for J-Frog. I'm a head of developer relations there now. This company is actually my first developer relations position so that was quite the change. We have a very similar story. Interesting. That's cool. We should talk about it...
# Processing chunk 10/67...
# Chunk 10:  cool that we should talk more about that. Yeah, sure. From my IDE to humans. What? From zero to two conferences. Yeah, so if you if you started learning software, I think you were going to get away from humans that yeah, no, sorry, one of the hardest problems to solve. Oh, absolutely. The human problems. Yeah, we need we need the folks that are willing and able to do that. Anyway, so,..
# Processing chunk 11/67...
# Chunk 11:  Anyway, so as I moved from developer position to developer relations, that also gave me a lot more exposure to these communities in open source. And one in particular was Jenkins. I love Jenkins. I mean, it's something I used all the time, right? So J-Vrog actually supports Jenkins in a way. We give them like a free storage space and bandwidth and stuff in order to maintain their project...
# Processing chunk 12/67...
# Chunk 12:  They have been able to maintain their project and build it and run tasks and all that stuff. It's pretty cool. We do that for a number of open source communities. And they in particular needed some help with resource usage. Because we noticed things were getting out of control. And we started monitoring that. And that was a really cool experience because that community is so great. It was just a matter of content...
# Processing chunk 13/67...
# Chunk 13:  It was just a matter of contacting them saying, hey, what can we do to help? And how can we make this better for you? And so that's something that we've been working on the last couple of months. And it came to great success. We actually got a session out of it. We're going to be talking about it and sharing that more because I think that's an important problem that a lot of even just organizations, not just open-sourish...
# Processing chunk 14/67...
# Chunk 14:  open source, organizations in general have. So that's one way to get involved, right? Yeah. Where can you help? And that was one place that I was able to help that committee. So tell us a little bit more about, let me back up just a tiny bit. Everybody wants to talk about AI. Of course. Right now, everybody's very excited. I mean, it's an exciting..
# Processing chunk 15/67...
# Chunk 15:  It's an exciting time to be in technology. No matter where you are in that software stack or in the life cycle, or you're involved in building applications, deploying the applications, whatever it is that you're doing. It is an interesting time with interesting and new challenges, security challenges. We've talked about it at length probably, but yeah, so tell me what you're interested in...
# Processing chunk 16/67...
# Chunk 16:  What you're interested in in this brave new world of ours at this inflection point in technology, how are you getting involved in that type of conversation? So, lots of playing around, lots of trying out the new stuff that's coming out. But the reality is that AI has been around a long time...
# Processing chunk 17/67...
# Chunk 17:  has been around a long time. And it's just probably the LLMs coming out, got everyone excited about it. People interested in it that had never heard about it before, never really cared before. They just didn't really see a lot of what was going on behind the scenes. There's so much AI that we deal with every day that I think people don't even realize...
# Processing chunk 18/67...
# Chunk 18:  don't even realize. Oh absolutely. But then mundane stuff that they don't even think about. Exactly. Exactly. Like things that monitor oil well. Exactly. Like, nobody thinks about that stuff. Exactly. I think the very first time I even encountered it really was just I was working on a project that was involved. It was exactly that. It was like monitoring a..
# Processing chunk 19/67...
# Chunk 19:  monitoring electricity and water usage, utility usage in households, and collecting all that data, and then analyzing that data and making predictions and adjusting things based on that data. Pretty cool. Also like DevOps. Getting into DevOps, that was one of the first things I had to learn as a developer. Now I was exposed to everything that happens in production...
# Processing chunk 20/67...
# Chunk 20:  production, so seeing all of the processes they're involved with detecting flaky tests, for example, or detecting abnormal behavior, things like that. That's all, yeah, that was all, you collect a bunch of data and then be able to analyze it and then be able to make decisions and make actions based on that...
# Processing chunk 21/67...
# Chunk 21:  Recently though, I have kind of a higher level of these projects. I'm looking for patterns. Like there's all these different things going on. Yes, yes. And all of these organizations are all trying to, you know, I like this use case where like just about every website you go to has like a chatbot...
# Processing chunk 22/67...
# Chunk 22:  has a chatbot, let us help you, type your question in here and we'll give you answers. After a while you start realizing are they all doing it the same way? Are they all trying to do things differently? Are they paying attention to how it's actually built under the covers? That's where my company was really interested in getting involved in this project called..
# Processing chunk 23/67...
# Chunk 23:  in this product called OPI. I said it. I said the product opened this long form for Enterprise AI. So it's just, you know, an attempt to standardize this to put things together in such a way that everyone can do it the same. We can all contribute. We can all pay attention to the details like security...
# Processing chunk 24/67...
# Chunk 24:  something I'm particularly interested in is when we build these things we build all the different components of the system that are required. Where do all of these components come from? Where does the code come from? Where do the dependencies come from? All of that provenance. Who's touched it along the way? Yeah, it's exactly. I have to clarify. I say provenance because..
# Processing chunk 25/67...
# Chunk 25:  because I have an art nerd background and I can't help myself. And I was like, what? What? Provenant? Provenant? It sounds kind of stuffy, but apologies I can't help myself. It just comes out of my mouth that way. That's okay. Anyway. No, that's very cool. So full disclosure, I'm slightly biased being that OPA is heavily..
# Processing chunk 26/67...
# Chunk 26:  I'm not overly, intel is heavily involved, obviously. I'm creating it, donating it, but I also leave the security working group. Yeah. Because it's, that's just, again, it's an interesting time to talk about the intersection of security and AI. Yes. And maybe this is my age showing, but I get nervous. I get nervous when everyone gets very excited about something and everyone jumps on it and tries to..
# Processing chunk 27/67...
# Chunk 27:  I'm sorry...
# Processing chunk 28/67...
# Chunk 28:  Maybe you accidentally checked in some credentials to GitHub. I don't know who would do that and then have to spend their day scrubbing it. Right. We've all done it. It's fine. It's not fine. Scrub it, but you know it happens. Re-write history. Yeah. We love that. Learning those special GitHub commands. Yes. Anyway, it was not designed...
# Processing chunk 29/67...
# Chunk 29:  It was not designed for that. It was designed to retain everything. It's cool. Google it. You can find out how to get rid of some of it. I'm going to go out with a tangent here. Tell me more about how does your work with your background and DevOps and the CICD work. How does that inform where..
# Processing chunk 30/67...
# Chunk 30:  What you're doing now getting more involved in this AI conversation? Well, something I am really interested in in my position is just processes that develop risk go through. And what I notice and when I talk to folks, especially in the AI and ML engineering field, I realize that that is a completely different group of people than I'm used to working with...
# Processing chunk 31/67...
# Chunk 31:  I'm used to working with. They have different processes. I remember the first time I encountered Jupyter Notebooks, for example. What is this? What are you doing here? This is a code snippet. You're just going to change it. You're going to throw it over the wall and that's it. Where's the process? Where's the process? Where is the, am I missing something? Isn't this just a, what do you call it? Oh, gosh...
# Processing chunk 32/67...
# Chunk 32:  I'm going to call it, oh gosh, the GitHub where you were you, Agist, isn't this just Agist? Right, right exactly. So learning that these folks come from a different background and have a completely different tool set made me realize, oh, there's a whole different world out there. Especially for my simplified view of just the..
# Processing chunk 33/67...
# Chunk 33:  of just the software development life cycle. There's another addition to it, like in the beginning, when you do the model development and stuff like that, it's a whole different cycle that happens there. You have to care about model drift and you've got to track all the changes that you made. Those are things I want to help support and get standardized across the board...
# Processing chunk 34/67...
# Chunk 34:  across the board so that the best practices that we've learned and worked with in the software engineering field apply to the ML engineering side of it as well. That's great. I mean it's similar to the things that I'm looking at from a little maybe a little bit more security perspective but what's new and different right? If we were used to building..
# Processing chunk 35/67...
# Chunk 35:  We were used to building this type of applications. How do we now need to think differently about, let's say, a generative AI application? What's the delta between a software lifecycle of an old school if we want to go on an application? Something new that relies on a base model and all of these new pieces of that puzzle...
# Processing chunk 36/67...
# Chunk 36:  How does that change how we look at it? Again, I'm looking at it. They're okay. What is new and different from a security angle? What's also new and different just from a deployment perspective? How does that change? Yeah, yeah, crazy. I remember the first time I encountered, I think there's a talk I went..
# Processing chunk 37/67...
# Chunk 37:  I think there's a talk I went to. It was a couple years ago now, but it was just explaining how you can adjust your prompts in such a way that you can get very unsafe responses and things like that. It was a whole discussion on how to build, you know, guardrails and how to pay attention to that stuff. That was all new to me and I felt like that's a whole new..
# Processing chunk 38/67...
# Chunk 38:  a whole new set of doors open to projects now that can experience those kind of vulnerabilities and those safety issues. It's no longer complexity, right? Yeah, it's no longer lines of code that you're just looking for. Remember back when I first learned about a sequel injection, right? And I'm like, oh, now I'm a smart..
# Processing chunk 39/67...
# Chunk 39:  Now I'm a smart developer. I know it all. I know just enough what I need to know to make everything safe and then this is a whole new chapter. I've been thinking about this also. So you're taking what used to be a fairly straightforward, something, an input field. Right. Just an input field. Well, now it's an input field. It's a prompt. Yeah. How is that?..
# Processing chunk 40/67...
# Chunk 40:  And how is that different from in what is sanitizing that look like and what is exactly what do those guard rails look like when you it's a much more complicated beast than Let's say the input fields of the past exactly and then the same goes with the generated output well, okay How you know where is the additional risk and complexity there? Yeah, yeah, yeah..
# Processing chunk 41/67...
# Chunk 41:  Yeah, and people come up with new and creative ways of getting around things. I remember just even my previous life as a job developer. I shouldn't say previous life. It's still my life. Still do that stuff today. But just the whole idea of using logs to break in and..
# Processing chunk 42/67...
# Chunk 42:  and cause problems. That was really interesting to me. And scary. Not just vulnerabilities like that, but also organizations that start using all of these models and stuff that are available to them. It's not just a safety issue. It might not be the correct word. But a liability..
# Processing chunk 43/67...
# Chunk 43:  But a liability issue is like data. The data that's being used that could possibly be exposed after prompting one of these engines and getting back some data that maybe is not for you. Right, exactly. It's not meant for you. Yeah. What is the curse? May you live in interesting times? Yeah...
# Processing chunk 44/67...
# Chunk 44:  Yeah, yeah, exactly. So here's your question, especially for somebody in your position, right? You lead a dev rail team. And which means you are constantly, you're in your whole team. You're constantly learning new things. You're constantly, you know, having to distill them and communicate them and process them for yourselves, but also to the benefit of the people you are kind of helping along the way...
# Processing chunk 45/67...
# Chunk 45:  helping along the way. So how do you approach that, especially right now when you're diving into something new? It's a new territory with generative AI and talking about models. What is your approach for both you and your team to encourage people like where do you tell them to get started? How do you get in the right frame of mind to..
# Processing chunk 46/67...
# Chunk 46:  to learn something that's a little bit out of your comfort zone. Yeah, so I struggle with this myself a little bit because there's a lot out there and it's hard to know where to start sometimes. So this is something that I appreciate about the OPM project is, I mean that's kind of one of my, giving me,..
# Processing chunk 47/67...
# Chunk 47:  I was giving it a starting point. And tree points, yeah, is just getting involved, figuring out how things work, how things are put together. One thing I've noticed is given my background and given my tendency to stick with what I know and like what I'm used to, it is a little more difficult for me to..
# Processing chunk 48/67...
# Chunk 48:  to discover new things like I watched so I have adult children right they're both playing a lot with AI right now and they show me stuff every day they just blows me away I'm like you did what you built that slide deck you made all those pictures so some of that stuff is still a little bit overwhelming to me and I'm just thinking about..
# Processing chunk 49/67...
# Chunk 49:  Just thinking about back when I was in school talking to my professors who were still during their time learning they were using the punch cards, right? Do you imagine? Sure, yeah. Like, to card loom. Sorry, I'm being a weaving nerd now. But yes. And I just wonder, you know, my generation was the IDE, right? We got the IDE and it made it a little..
# Processing chunk 50/67...
# Chunk 50:  And it made it a lot more accessible, easier to learn, certainly not take as much time as correcting punch cards if you get one thing wrong, right, in your stack of cards or you happen to drop them. So I'm just thinking I probably feel very similar in a way. Oh yeah. Watching the next generation pick up these things and pick up these tools...
# Processing chunk 51/67...
# Chunk 51:  up these tools like they're nothing. Because it's their first time, right? So yeah, I think there's quite a bit of transition that's going to take place between us and the next. I'm interested to see how that turns out. It's also interesting, especially I would love to hear your perspective about developer identity in the age of..
# Processing chunk 52/67...
# Chunk 52:  identity in the age of AI with so much AI generated code and probably more on the way right vibe coding I just learned about that. I think it's thrown around right and wonder like how does that impact you especially for you know the way that you think about communicating again best practice..
# Processing chunk 53/67...
# Chunk 53:  Again, best practices for the lifecycle, best practices for things like CI, CD, and deployment, and all of the dev ops concerns that you are so connected to in your work. How does this change? It's adding additional team members. How do you fit that into the..
# Processing chunk 54/67...
# Chunk 54:  into the machine. Yeah. If you think of a pipeline, I'm kind of visually picturing the CDI-CD pipeline with all the different stages running as they do. We're talking about Jenkins. And then you insert this random identity list contributor, basically, is what it is...
# Processing chunk 55/67...
# Chunk 55:  it is right? And how does that change the way we think about the making of software? Does it maybe it doesn't have to but I don't know. I find myself getting caught up in the details like how things are put together and then just being aware of all of the tripping points that you can run into. But this this approach I just see if..
# Processing chunk 56/67...
# Chunk 56:  I just see a future where we're going to be so focused more on the requirements and the outcomes rather than how it's made and how it's done. And that might actually be more healthy. How many times has a developer have you been sitting working on a project and you just get stuck on this one thing and you're like, I'm just going to make it work?..
# Processing chunk 57/67...
# Chunk 57:  make it work and sure you make it work by the end it doesn't do what it's supposed to do. That's a good point. We get very focused on the ways in which we are used to building these things. Maybe that doesn't matter anymore. Maybe the entire process, maybe we're ready for a complete shake-up of all of it...
# Processing chunk 58/67...
# Chunk 58:  All of it. Maybe that pipeline doesn't look like anything that we imagine right now. Yeah, maybe maybe maybe there's some components that we don't have yet that We should yeah, maybe and maybe to replace some of the things we do have yeah, yeah So what is your what would you take away for people listening to this conversation be like what do you what do you..
# Processing chunk 59/67...
# Chunk 59:  be like what do you want people to know and think about as they're navigating you know as a developer in this kind of dynamic world where things are constantly changing, constantly evolving and we're again in a very interesting point. I want to say don't be afraid to try these new things and play but I also..
# Processing chunk 60/67...
# Chunk 60:  play, but I also want to stress how important it is to have a safe place to do that. I mean, this is why we take children to the playground. They have a safe place, they can try new things, they can test their abilities, test their limits without running out into the street and getting hit by a car. So I do..
# Processing chunk 61/67...
# Chunk 61:  I do just from my experience in my background, I do have some fear that a lot of, I'm just curious what's going to come down the pipe here as far as security is concerned. So there's going to be stuff that we haven't even thought of yet. And unfortunately, humans...
# Processing chunk 62/67...
# Chunk 62:  We're not so good at preventing problems. We respond. Respond when they happen and I'm just nervous about what the next thing is going to be that's going to happen. Yeah. Before we think about it. Monsters may we create before we rain ourselves in a little bit. Yeah. Exactly. That's a fair concern. But we're doing that. We're trying..
# Processing chunk 63/67...
# Chunk 63:  doing that, we're trying, I think, you know, projects like Opiea, that's one of the goals. I guess people are safe starting place. Yeah. Yeah. Fantastic. Well, I love it. Is there anything that you wanted to talk about that we didn't get to? Oh, goodness. You know, I think just encouraging people to getting involved with these projects because even..
# Processing chunk 64/67...
# Chunk 64:  Even me getting involved, it seemed ridiculous at first because I'm like, I don't have that background at all. I don't really know how it's done. But the important thing about getting people like that involved is that you get explanations, you get documentation, you get starting places for people that are learning because think about it. There's always going..
# Processing chunk 65/67...
# Chunk 65:  There's always going to be a new person. There's always going to be a next generation. Hopefully. Yeah. That's the hope. Yes. That's right. Otherwise, the soul of this infrastructure comes crashing down. Yeah. Exactly. So making sure to have these starting places, I think it is really good. Encouraging people, you know, even if you just come and listen, like I said before, I have an adult..
# Processing chunk 66/67...
# Chunk 66:  before I have adult children and there's a lot of this stuff is, you know, maybe overwhelming, but once you start listening, seeing how people behave with each other, see how people interact with each other, I love a lot of the open source communities just learning how they're governed, how they're organized, how you communicate, how you start working on something. Like I think one of the valuable things I learned..
# Processing chunk 67/67...
# Chunk 67:  valuable things I learned right away was you don't just jump in and just start doing stuff. The first thing you do is communicate, introduce yourself, talk to people, find out what's important, find out what the priorities are, who's working on what, who are the maintainers, building those relationships. And then once you've done that, then you start to begin knowing. Find out where the gaps are, find out, hey,..
# Processing chunk 68/67...
# Chunk 68:  I'm sorry, find out where exactly where you most useful and what is most useful to you. Exactly. Exactly. I love it. Well, thank you so much. And I hope if you're listening, you will join both of us in various open source communities, be it open platform for enterprise AI or possibly open as a source security foundation. Yeah. Help us make these things stronger...
# Processing chunk 69/67...
# Chunk 69:  things stronger so that we can all use them and then we can all, you know, do the next best thing. Awesome. Well thank you so much. Thanks. You've been listening to OpenItIntel. Be sure to check out more from the OpenItIntel podcast at open.intel.com slash podcast and at OpenItIntel on Twitter. We hope you join us again next..
# Processing chunk 70/67...
# Chunk 70:  Hope you join us again next time to geek out about open source...
#
#
#  Total length: 23604 characters
# Audio path: downloads\OpenAtIntel_Ep111_MelissaMcKay-JFrog.mp3
# Word count: 4283
#  My company was really interested in getting involved in this product called a Kia. So it's, you know, an attempt to standardize this. To put things together in such a way that everyone can do it the same, we can all contribute, we can all pay attention to the details. Welcome to the OpenItIntel podcast, where we're all about open source from software  source from software to security to innovation and beyond. I'm your host, Catherine Druckmann, an open source evangelist at Intel, bringing you leading edge, free-ranging conversations from some of the best minds in the open source community. Let's get into it! I spoke with Melissa McCay of J. Frog about the excitement and challenges in developing generative AI applications  applications, and why open source participation is so critical to fostering growth and innovation and technology. Join us. Hey Melissa, thank you for joining me. I really appreciate you sitting down and taking the time out of your day to talk to me about Oatspull or AI and stuff. Thank you. Yeah, Asurin is always a pleasure for sure.  So first, why don't you tell us a little bit more about who you are and what you do and especially what you do in open source communities? Okay, cool. I think this is always a valuable question because I think there's a lot of folks out there that don't realize there's a lot of different personas and different types of people that are contributing to open source. And if you think that you are too late to the game or not technical  or not technical enough, that is not a good enough reason to not be able to contribute to open source projects. So there's lots of different ways to do that. I began, I was a developer, principal developer at my last position, so a lot of my career has been just, you know, being low on the table, just being, you know, sitting at my desk and grabbing tasks off of Jira and, you know,  I am fixing bugs. And so dealing with open source for me for the most part, especially in the beginning of my career, was just using it. Right? And I didn't really understand the whole ecosystem behind it. I just had a job to do and that's what I did every day. Then as you get more experience and more exposure, you start meeting different people, maybe  people, maybe you go to a few conferences, you start realizing, oh wow, this is a lot bigger world than I realized. And that's exactly what happened. Then I started getting aware and more involved in foundations. That was probably the big stepping stone for me getting involved with open source communities, at all. Starting to learn how they worked, how they  they worked, how they give these projects a little more credibility when they go through the process of improvement and being able to have the communities in these projects that make them better, make them reliable. You have the maintainers you can reach out to. So that's where I started. Since then, being able to be involved with these communities  I can give one specific example that I'm kind of really excited about because it happened recently. My company, I work for J-Frog. I'm a head of developer relations there now. This company is actually my first developer relations position so that was quite the change. We have a very similar story. Interesting. That's cool. We should talk about it.  cool that we should talk more about that. Yeah, sure. From my IDE to humans. What? From zero to two conferences. Yeah, so if you if you started learning software, I think you were going to get away from humans that yeah, no, sorry, one of the hardest problems to solve. Oh, absolutely. The human problems. Yeah, we need we need the folks that are willing and able to do that. Anyway, so,  Anyway, so as I moved from developer position to developer relations, that also gave me a lot more exposure to these communities in open source. And one in particular was Jenkins. I love Jenkins. I mean, it's something I used all the time, right? So J-Vrog actually supports Jenkins in a way. We give ...

# %%
    print(f"Audio shape: {waveform.shape}")
# Out:
# Audio shape: torch.Size([1, 23350494])

# %%
from teapotai import TeapotAI
teapot_ai = TeapotAI(documents=transcription_parts)
# Out:
# C:\Users\gta\Documents\seshu\02_Speech_n_Text\Final\my-own\AI-PC-Code-Samples\Audio-RAG\Podcast-RAG\.venv\Lib\site-packages\teapotai\teapotai.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# C:\Users\gta\Documents\seshu\02_Speech_n_Text\Final\my-own\AI-PC-Code-Samples\Audio-RAG\Podcast-RAG\.venv\Lib\site-packages\pydantic\_internal\_fields.py:198: UserWarning: Field name "schema" in "TeapotTool" shadows an attribute in parent "BaseModel"
#   warnings.warn(
#  _____                      _         _    ___        __o__    _;;
# |_   _|__  __ _ _ __   ___ | |_      / \  |_ _|   __ /-___-\__/ /
#   | |/ _ \/ _` | '_ \ / _ \| __|    / _ \  | |   (  |       |__/
#   | |  __/ (_| | |_) | (_) | |_    / ___ \ | |    \_|~~~~~~~|
#   |_|\___|\__,_| .__/ \___/ \__/  /_/   \_\___|      \_____/
#                |_|
# Loading Model
# C:\Users\gta\Documents\seshu\02_Speech_n_Text\Final\my-own\AI-PC-Code-Samples\Audio-RAG\Podcast-RAG\.venv\Lib\site-packages\sklearn\base.py:440: InconsistentVersionWarning: Trying to unpickle estimator LabelBinarizer from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\gta\Documents\seshu\02_Speech_n_Text\Final\my-own\AI-PC-Code-Samples\Audio-RAG\Podcast-RAG\.venv\Lib\site-packages\sklearn\base.py:440: InconsistentVersionWarning: Trying to unpickle estimator MLPClassifier from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Generating embeddings for documents...
# Document Embedding: 100%|████████████████████████████████████████████████████████████| 70/70 [00:01<00:00, 44.60 doc/s]

# %%
# %%time
# Get the answer using RAG

question = "Whos is the host here?"
answer = teapot_ai.chat([
    {
        "role":"system",
        "content": "You are an agent designed to answer the questions."
    },
    {
        "role":"user",
        "content": question
    }
])
print(answer)
# Out:
# The host is Catherine Druckmann.
# CPU times: total: 8.84 s
# Wall time: 1.79 s

# %%
# %%time
# Get the answer using RAG

question = "what was the work of the host here"
answer = teapot_ai.chat([
    {
        "role":"system",
        "content": "You are an agent designed to answer the questions."
    },
    {
        "role":"user",
        "content": question
    }
])
print(answer)
# Out:
# The host was responsible for delivering the content on the website.
# CPU times: total: 7.52 s
# Wall time: 1.8 s

# %%
# %%time
# Get the answer using RAG

question = "What is OPEA?"
answer = teapot_ai.chat([
    {
        "role":"system",
        "content": "You are an agent designed to answer the questions."
    },
    {
        "role":"user",
        "content": question
    }
])
print(answer)
# Out:
# OPEA is an acronym for Open Platform for Enterprise Applications.
# CPU times: total: 6.11 s
# Wall time: 1.59 s

# %%
# %%time
# Get the answer using RAG

question = "What is the podcast we are listening to?"
answer = teapot_ai.chat([
    {
        "role":"system",
        "content": "You are an agent designed to answer the questions."
    },
    {
        "role":"user",
        "content": question
    }
])
print(answer)
# Out:
# The podcast we are listening to is OpenItIntel.
# CPU times: total: 7.7 s
# Wall time: 1.82 s

# %%
# %%time
# Get the answer using RAG

question = "What is the summary of the podcast?"
answer = teapot_ai.chat([
    {
        "role":"system",
        "content": "You are an agent designed to answer the questions."
    },
    {
        "role":"user",
        "content": question
    }
])
print(answer)
